# %% [markdown]
# # Wstęp do biblioteki Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Data Structure

# %%
series = pd.Series([1,2,3,np.nan])
series
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# dtype: float64

# %%
dates = pd.date_range(start = '2018-11-21', end = '2018-12-31', freq = 'D')
dates
# Out:
# DatetimeIndex(['2018-11-21', '2018-11-22', '2018-11-23', '2018-11-24',
#                '2018-11-25', '2018-11-26', '2018-11-27', '2018-11-28',
#                '2018-11-29', '2018-11-30', '2018-12-01', '2018-12-02',
#                '2018-12-03', '2018-12-04', '2018-12-05', '2018-12-06',
#                '2018-12-07', '2018-12-08', '2018-12-09', '2018-12-10',
#                '2018-12-11', '2018-12-12', '2018-12-13', '2018-12-14',
#                '2018-12-15', '2018-12-16', '2018-12-17', '2018-12-18',
#                '2018-12-19', '2018-12-20', '2018-12-21', '2018-12-22',
#                '2018-12-23', '2018-12-24', '2018-12-25', '2018-12-26',
#                '2018-12-27', '2018-12-28', '2018-12-29', '2018-12-30',
#                '2018-12-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
dataframe = pd.DataFrame(data = {'x': [1,2,3],
                                 'y': 1.,
                                 'date': pd.Timestamp('2018-11-21'),
                                 'name': ['foo', 'bar', 'ant'],
                                 'type': pd.Categorical(['test', 'train', 'train'])})
dataframe
# Out:
#         date name   type  x    y
# 0 2018-11-21  foo   test  1  1.0
# 1 2018-11-21  bar  train  2  1.0
# 2 2018-11-21  ant  train  3  1.0

# %% [markdown]
# Sprawdzenie typów danych w kolumnach

# %%
dataframe.dtypes
# Out:
# date    datetime64[ns]
# name            object
# type          category
# x                int64
# y              float64
# dtype: object

# %% [markdown]
# # Zadanie

# %% [markdown]
# Stwórz ramkę danych, która będzie zawierać następujące kolumny:
# - x - liczby od 0 do 99
# - eps - 100 liczb z rozkładu normalnego N(0,1)
# - date - daty od dzisiaj do kolejnych 100 dni (argument periods w date_range)
# - type - 50. pierwszych wierszy, to zmienna kategoryczna train, a drugie 50. wierszy, to zmienna kategoryczna test
#
# Następnie sprawdź typy danych w utworzonych kolumnach

# %%
# Your code goes here

# %% [markdown]
# #### Reading data

# %%
df = pd.read_csv('titanic.csv')

# %% [markdown]
# #### Viewing data

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
df = pd.read_csv('titanic.csv')

# %%
df.tail(3)
# Out:
#       pclass  survived                       name   sex   age  sibsp  parch  \
# 1306       3         0  Zakarian, Mr. Mapriededer  male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin  male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo  male  29.0      0      0
#
#       ticket   fare cabin embarked boat   body home.dest
# 1306    2656  7.225   NaN        C  NaN  304.0       NaN
# 1307    2670  7.225   NaN        C  NaN    NaN       NaN
# 1308  315082  7.875   NaN        S  NaN    NaN       NaN

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1309, step=1)

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1, 1, 'Allen, Miss. Elisabeth Walton', ..., '2', nan,
#         'St Louis, MO'],
#        [1, 1, 'Allison, Master. Hudson Trevor', ..., '11', nan,
#         'Montreal, PQ / Chesterville, ON'],
#        [1, 0, 'Allison, Miss. Helen Loraine', ..., nan, nan,
#         'Montreal, PQ / Chesterville, ON'],
#        ...,
#        [3, 0, 'Zakarian, Mr. Mapriededer', ..., nan, 304.0, nan],
#        [3, 0, 'Zakarian, Mr. Ortin', ..., nan, nan, nan],
#        [3, 0, 'Zimmerman, Mr. Leo', ..., nan, nan, nan]], dtype=object)

# %%
type(df.values)
# Out:
# numpy.ndarray

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# # Zadanie

# %% [markdown]
# Na poprzednio utworzonej ramce danych sprawdź wyżej wymienione komendy. Jaka jest najmniejsza wartość w kolumnie 'eps'?

# %%
# Your code goes here

# %% [markdown]
# #### Sorting values

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
sorted_by_age = df.sort_values(by = 'age')
sorted_by_age.head()
# Out:
#       pclass  survived                                     name     sex   age  \
# 763        3         1  Dean, Miss. Elizabeth Gladys "Millvina"  female  0.17
# 747        3         0  Danbom, Master. Gilbert Sigvard Emanuel    male  0.33
# 1240       3         1          Thomas, Master. Assad Alexander    male  0.42
# 427        2         1                Hamalainen, Master. Viljo    male  0.67
# 1111       3         0           Peacock, Master. Alfred Edward    male  0.75
#
#       sibsp  parch              ticket     fare cabin embarked boat  body  \
# 763       1      2           C.A. 2315  20.5750   NaN        S   10   NaN
# 747       0      2              347080  14.4000   NaN        S  NaN   NaN
# 1240      0      1                2625   8.5167   NaN        C   16   NaN
# 427       1      1              250649  14.5000   NaN        S    4   NaN
# 1111      1      1  SOTON/O.Q. 3101315  13.7750   NaN        S  NaN   NaN
#
#                        home.dest
# ...

# %%
sorted_by_age.sort_index(ascending = False).head()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN

# %% [markdown]
# # Zadanie

# %% [markdown]
# Posortuj malejąco swoją ramkę danych względem zmiennej 'eps'.

# %%
# Your code goes here

# %% [markdown]
# #### Selection

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %% [markdown]
# ###### Selecting columns

# %%
df.name.head()
# Out:
# 0                      Allen, Miss. Elisabeth Walton
# 1                     Allison, Master. Hudson Trevor
# 2                       Allison, Miss. Helen Loraine
# 3               Allison, Mr. Hudson Joshua Creighton
# 4    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# Name: name, dtype: object

# %%
df['name'].head()
# Out:
# 0                      Allen, Miss. Elisabeth Walton
# 1                     Allison, Master. Hudson Trevor
# 2                       Allison, Miss. Helen Loraine
# 3               Allison, Mr. Hudson Joshua Creighton
# 4    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# Name: name, dtype: object

# %% [markdown]
# ###### Selecting by Label

# %%
dataframe
# Out:
#         date name   type  x    y
# 0 2018-11-21  foo   test  1  1.0
# 1 2018-11-21  bar  train  2  1.0
# 2 2018-11-21  ant  train  3  1.0

# %%
dataframe.index = ['a', 'b', 'c']

# %%
dataframe
# Out:
#         date name   type  x    y
# a 2018-11-21  foo   test  1  1.0
# b 2018-11-21  bar  train  2  1.0
# c 2018-11-21  ant  train  3  1.0

# %%
dataframe.loc['b']
# Out:
# date    2018-11-21 00:00:00
# name                    bar
# type                  train
# x                         2
# y                         1
# Name: b, dtype: object

# %%
dataframe.loc['b':]
# Out:
#         date name   type  x    y
# b 2018-11-21  bar  train  2  1.0
# c 2018-11-21  ant  train  3  1.0

# %% [markdown]
# #### Selection by position

# %%
dataframe
# Out:
#         date name   type  x    y
# a 2018-11-21  foo   test  1  1.0
# b 2018-11-21  bar  train  2  1.0
# c 2018-11-21  ant  train  3  1.0

# %%
dataframe.iloc[2]
# Out:
# date    2018-11-21 00:00:00
# name                    ant
# type                  train
# x                         3
# y                         1
# Name: c, dtype: object

# %%
dataframe.iloc[:1]
# Out:
#         date name  type  x    y
# a 2018-11-21  foo  test  1  1.0

# %%
dataframe.iloc[:1, 1:]
# Out:
#   name  type  x    y
# a  foo  test  1  1.0

# %% [markdown]
# # Zadanie

# %% [markdown]
# Z wcześniej utworzonej ramki danych:
# - wybierz kolumnę eps i przypisz do zmiennej wartosc_losowe
# - wybierz pierwsze 50. wierszy z kolumny date

# %%
# Your code goes here

# %% [markdown]
# #### Boolean Indexing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
# pclass       1309 non-null int64
# survived     1309 non-null int64
# name         1309 non-null object
# sex          1309 non-null object
# age          1046 non-null float64
# sibsp        1309 non-null int64
# parch        1309 non-null int64
# ticket       1309 non-null object
# fare         1308 non-null float64
# cabin        295 non-null object
# embarked     1307 non-null object
# boat         486 non-null object
# body         121 non-null float64
# home.dest    745 non-null object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.2+ KB

# %%
df2 = df.dropna(subset = ['age'])
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1046 entries, 0 to 1308
# Data columns (total 14 columns):
# pclass       1046 non-null int64
# survived     1046 non-null int64
# name         1046 non-null object
# sex          1046 non-null object
# age          1046 non-null float64
# sibsp        1046 non-null int64
# parch        1046 non-null int64
# ticket       1046 non-null object
# fare         1045 non-null float64
# cabin        272 non-null object
# embarked     1044 non-null object
# boat         417 non-null object
# body         120 non-null float64
# home.dest    685 non-null object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 122.6+ KB

# %%
df2.age > 18
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11      False
# 12       True
# 13       True
# 14       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
# 30       True
#         ...
# 1269     True
# 1270     True
# 1271     True
# 1272     True
# 1273    False
# 1274     True
# 1275    False
# 1276     True
# 1277     True
# 1278     True
# 1279    False
# 1280     True
# 1281     True
# 1285     True
# 1286     True
# 1287     True
# 1288    False
# 1289     True
# 1290     True
# 1294     True
# 1295     True
# 1296     True
# 1298     True
# 1299     True
# 1300    False
# 1301     True
# 1304    False
# 1306     True
# 1307     True
# 1308     True
# ...

# %%
df2[df2.age > 18]
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 12         1         1                      Aubart, Mme. Leontine Pauline
# 13         1         1                       Barber, Miss. Ellen "Nellie"
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
# ...

# %% [markdown]
# # Zadanie

# %% [markdown]
# Z wcześniej utworzonej ramki danych stwórz ramkę danych, której wartości w kolumnie eps są tylko dodatnie.

# %%
# Your code goes here

# %% [markdown]
# #### Setting values

# %%
dataframe
# Out:
#         date name   type  x    y
# a 2018-11-21  foo   test  1  1.0
# b 2018-11-21  bar  train  2  1.0
# c 2018-11-21  ant  train  3  1.0

# %%
dataframe['eps'] = [1,2,3]
dataframe
# Out:
#         date name   type  x    y  eps
# a 2018-11-21  foo   test  1  1.0    1
# b 2018-11-21  bar  train  2  1.0    2
# c 2018-11-21  ant  train  3  1.0    3

# %%
dataframe.loc[:,'x'] = 3
dataframe
# Out:
#         date name   type  x    y  eps
# a 2018-11-21  foo   test  3  1.0    1
# b 2018-11-21  bar   test  3  1.0    2
# c 2018-11-21  ant  train  3  1.0    3

# %%
dataframe.loc['b', 'type'] = 'test'
dataframe
# Out:
#         date name   type  x    y  eps
# a 2018-11-21  foo   test  3  1.0    1
# b 2018-11-21  bar   test  3  1.0    2
# c 2018-11-21  ant  train  3  1.0    3

# %% [markdown]
# # Zadanie

# %% [markdown]
# Dodaj do swojej ramki danych kolumnę $y = x*eps$. Następnie dla danych z wartością test w kolumnie $type$ zamień $y$ na wartość $np.nan$. Dodatkowo zamień wartości z kolumny eps, które są $\le 0$ na $0$.

# %%
# Your code goes here

# %% [markdown]
# # Materiały do dalszej nauki:
# - https://pandas.pydata.org/pandas-docs/stable/10min.html
# - https://pandas.pydata.org/pandas-docs/stable/tutorials.html
